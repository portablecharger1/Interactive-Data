# %%
import pandas as pd

# %%
data_dict = {'a': [1,2,3], 'b':[4,5,6]}
data_list = [{'a': 1, 'b': 4}, {'a': 2, 'b': 5}, {'a': 3, 'b': 6}]

dat = pd.DataFrame(data_dict)
dat
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat2 = pd.DataFrame(data_list)
dat2
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat.head(1)
# Out:
#    a  b
# 0  1  4

# %%
dat.tail(1)
# Out:
#    a  b
# 2  3  6

# %%
dat['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
dat.loc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.iloc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
len(dat.index)
# Out:
# 3

# %%
len(dat.columns)
# Out:
# 2

# %%
dat[["a",'b']]
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat[dat['a'] > 2]
# Out:
#    a  b
# 2  3  6

# %%
dat[dat['a'] > 2]['a']
# Out:
# 2    3
# Name: a, dtype: int64

# %%
dat.write_csv()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xk/tp669tv92fs5hcjn5nz2bzth0000gn/T/ipykernel_1267/1500405319.py in ?()
# ----> 1 dat.write_csv()
#
# /opt/anaconda3/envs/indata/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'write_csv'

# %%
dat = pd.DataFrame(data_dict)
dat.to_csv("pandasChallange")

# %% [markdown]
# 1. it lets us quickly see the changes we make
# 2. it lets people explore the data themselves and helps prevent an overload of information
# 3. i do like the idea of a community building something open source together, making plug ins to help streamline the workload and prossess. however, this can lead to a barrer of entry that can make it difficult for new people to join in. if you need to know about all the plugins and how to use them, its a lot more difficult than just downloading a corporate software that had instructions built in.
