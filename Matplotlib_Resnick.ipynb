# %%
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# Im choosing to do a histogram, working in broadcast, i could use a histogram for viewer demographics.

# %%
data = pd.read_csv('cces_example_data.csv')
data.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig1, ax1 = plt.subplots()
ax1.set_xlabel('Age Histogram')
ax1.set_ylabel('Political Identity')
plt.show()

# %%
data['Evaluation']
# Out:
# 0      0
# 1      0
# 2      2
# 3      0
# 4      0
#       ..
# 654    3
# 655    0
# 656    0
# 657    2
# 658    2
# Name: Evaluation, Length: 659, dtype: int64

# %%
data['Evaluation'].keys()
# Out:
# RangeIndex(start=0, stop=659, step=1)

# %% [markdown]
# i dont know what this means

# %%
type(data['Evaluation'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# I have no clue what that means

# %%
EvDS = data.groupby('Evaluation').count()['caseid']
EvDS
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# Name: caseid, dtype: int64

# %% [markdown]
# the number of each Evaluation based on the case ID
# EvDS mean Evaluation Data Set

# %%
fig2, ax2 = plt.subplots()
ax2.bar(x = EvDS.index, height=EvDS.values)
plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(data['ConMediaUse'], data['ImmiPhobia'])

plt.show()

# %% [markdown]
# If we wanted to stick to a scatter plot, what we could do is add color based on gender, then add some jitter to seperate the points some to make it more clear the amount of data at each point. You have to be careful about that as, as Wilk says in chaper 18 in reffrince to figure 18.4 "City fuel economy versus engine displacement. By adding too much jitter to the points, we have created a visualization that does not accurately reflect the underlying dataset." you can also use size instead of color and jitter to show how many people are in each section.
