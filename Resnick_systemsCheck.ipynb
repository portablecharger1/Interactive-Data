# %% [markdown]
# # Systems Check
# ### Daniel Resnick
# ##### EMAT 62110
#
# making a list
# - thing one
# 1. Thing 1
#
# *italics* **bold**
#
# from this class I want ot learn more about how to work with data and how I can utilize it in my work
#
# ![image](https://assets-prd.ignimgs.com/2022/07/07/startrek-voy-1657226184312.jpg)

# %%
my_name = "Daniel"
my_name
def give_name():
    print(my_name)

give_name()
# Out:
# Daniel

# %%
def return_name():
    return my_name

new_name = return_name()
